# %% [markdown]
# ## Connect to the data and load it

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("project.db")

df = pd.read_sql_query("SELECT * FROM AQI_Record", conn)

conn.close()

# %% [markdown]
# #### View and review the data

# %%
df.head(10)
# Out:
#    state_code  county_code        date  aqi                        category  \
# 0           1            3  2025-01-01   20                            Good
# 1           2           20  2025-01-01   88                        Moderate
# 2           4            1  2025-01-01   22                            Good
# 3           5           19  2025-01-01   26                            Good
# 4           6            7  2025-01-01   71                        Moderate
# 5           1            3  2025-01-02   55                        Moderate
# 6           2           20  2025-01-02  120  Unhealthy for Sensitive Groups
# 7           6            7  2025-01-03  160                       Unhealthy
#
#   parameter_name    site_code
# 0          PM2.5  01-003-0010
# 1          PM2.5  02-020-0045
# 2           PM10  04-001-1003
# 3          Ozone  05-019-9991
# 4          PM2.5  06-007-0008
# 5          Ozone  01-003-0010
# 6          PM2.5  02-020-0045
# 7           PM10  06-007-0008

# %%
df.shape
# Out:
# (8, 7)

# %% [markdown]
# ## Converting Columns to Category

# %% [markdown]
# ## Before optimization

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   state_code      8 non-null      int64
#  1   county_code     8 non-null      int64
#  2   date            8 non-null      object
#  3   aqi             8 non-null      int64
#  4   category        8 non-null      object
#  5   parameter_name  8 non-null      object
#  6   site_code       8 non-null      object
# dtypes: int64(3), object(4)
# memory usage: 580.0+ bytes

# %%
df.memory_usage(deep=True)
# Out:
# Index             132
# state_code         64
# county_code        64
# date              472
# aqi                64
# category          467
# parameter_name    430
# site_code         480
# dtype: int64

# %% [markdown]
# ## After Optimization

# %%
df['state_code'] = df['state_code'].astype('category')
df['county_code'] = df['county_code'].astype('category')
df['parameter_name'] = df['parameter_name'].astype('category')
df['category'] = df['category'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   state_code      8 non-null      category
#  1   county_code     8 non-null      category
#  2   date            8 non-null      object
#  3   aqi             8 non-null      int64
#  4   category        8 non-null      category
#  5   parameter_name  8 non-null      category
#  6   site_code       8 non-null      object
# dtypes: category(4), int64(1), object(2)
# memory usage: 1.1+ KB

# %%
# Check memory usage after
df.memory_usage(deep=True)
# Out:
# Index             132
# state_code        220
# county_code       220
# date              472
# aqi                64
# category          427
# parameter_name    277
# site_code         480
# dtype: int64

# %%
df.head(10)
# Out:
#   state_code county_code        date  aqi                        category  \
# 0          1           3  2025-01-01   20                            Good
# 1          2          20  2025-01-01   88                        Moderate
# 2          4           1  2025-01-01   22                            Good
# 3          5          19  2025-01-01   26                            Good
# 4          6           7  2025-01-01   71                        Moderate
# 5          1           3  2025-01-02   55                        Moderate
# 6          2          20  2025-01-02  120  Unhealthy for Sensitive Groups
# 7          6           7  2025-01-03  160                       Unhealthy
#
#   parameter_name    site_code
# 0          PM2.5  01-003-0010
# 1          PM2.5  02-020-0045
# 2           PM10  04-001-1003
# 3          Ozone  05-019-9991
# 4          PM2.5  06-007-0008
# 5          Ozone  01-003-0010
# 6          PM2.5  02-020-0045
# 7           PM10  06-007-0008

# %% [markdown]
# ## Using .query() for Filtering

# %% [markdown]
# ## Before optimization

# %%
good_before = df[df['category'] == 'Good']

# %%
good_before.head()
# Out:
#   state_code county_code        date  aqi category parameter_name    site_code
# 0          1           3  2025-01-01   20     Good          PM2.5  01-003-0010
# 2          4           1  2025-01-01   22     Good           PM10  04-001-1003
# 3          5          19  2025-01-01   26     Good          Ozone  05-019-9991

# %% [markdown]
# ## After Optimization

# %%
# Using query method
good_after = df.query("category == 'Good'")

# %%
good_after.head()
# Out:
#   state_code county_code        date  aqi category parameter_name    site_code
# 0          1           3  2025-01-01   20     Good          PM2.5  01-003-0010
# 2          4           1  2025-01-01   22     Good           PM10  04-001-1003
# 3          5          19  2025-01-01   26     Good          Ozone  05-019-9991

# %% [markdown]
# ## Using set_index() for Faster Lookups

# %% [markdown]
# ## Before Optimization

# %%
california_before = df[df['state_code'] == 6]

# %%
california_before
# Out:
#   state_code county_code        date  aqi   category parameter_name  \
# 4          6           7  2025-01-01   71   Moderate          PM2.5
# 7          6           7  2025-01-03  160  Unhealthy           PM10
#
#      site_code
# 4  06-007-0008
# 7  06-007-0008

# %% [markdown]
# ## After optimization

# %%
df_indexed = df.set_index('state_code')

# %%
california_after = df_indexed.loc[6]

# %%
california_after
# Out:
#            county_code        date  aqi   category parameter_name    site_code
# state_code
# 6                    7  2025-01-01   71   Moderate          PM2.5  06-007-0008
# 6                    7  2025-01-03  160  Unhealthy           PM10  06-007-0008
